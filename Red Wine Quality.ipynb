# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
maindt = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv")

# %%
maindt
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
maindt.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
maindt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
maindt.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
maindt.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
maindt['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(maindt['quality']);
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Class imbalance issue

# %%
x=maindt.drop("quality",axis=1)
y = maindt['quality']

# %%
y.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
y.shape
x.shape
# Out:
# (1599, 11)

# %%
#!pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
obj = SMOTE()
x, y = obj.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 4    681
# 6    681
# 8    681
# 3    681
# 5    681
# 7    681
# Name: quality, dtype: int64

# %%
x.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# dtype: object

# %% [markdown]
# Faetures are float type

# %%
y.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# Label is int type

# %%
x.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4086.000000       4086.000000  4086.000000     4086.000000
# mean        8.385509          0.579277     0.276569        2.574240
# std         1.667731          0.242489     0.203070        1.193656
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.200000          0.390000     0.074383        1.929049
# 50%         8.075977          0.540000     0.273634        2.200000
# 75%         9.453706          0.714161     0.447545        2.730021
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4086.000000          4086.000000           4086.000000  4086.000000
# mean      0.090187            13.685345             37.289220     0.996518
# std       0.048176             9.890851             29.121770     0.001885
# ...

# %%
len(maindt.columns)
# Out:
# 12

# %%
coln = list(maindt.columns)
colcount = len(maindt.columns)
x=0
for col in maindt.columns:
    if x < colcount:
        sns.displot(maindt[coln[x]])
        x=x+1

# %% [markdown]
# Skewness detected is all columns

# %%
plt.figure(figsize=(20,50))
colcount = len(maindt.columns)
x=1
for col in maindt:
    if x <= colcount:
        ax= plt.subplot(10,3,x)
        sns.boxplot(maindt[col],orient='v')
        plt.xlabel(col,fontsize=10)
    x=x+1
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
# ...

# %% [markdown]
# Ouliers found in all features

# %%
plt.figure(figsize=(20,50))
colcount = len(maindt.columns)
x=1
for col in maindt:
    if x <= colcount:
        ax= plt.subplot(10,3,x)
        sns.distplot(maindt[col])
       # plt.scatter(y=maindt[col],x=maindt['quality'])
        plt.xlabel(col,fontsize=10)
    x=x+1
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Skewness detected in all the columns except for density and ph

# %%
orgshape = maindt.shape
orgshape
# Out:
# (1599, 12)

# %%
q1 = maindt.quantile(0.25)
q3 = maindt.quantile(0.75)
iqr = q3-q1
q3
# Out:
# fixed acidity            9.200000
# volatile acidity         0.640000
# citric acid              0.420000
# residual sugar           2.600000
# chlorides                0.090000
# free sulfur dioxide     21.000000
# total sulfur dioxide    62.000000
# density                  0.997835
# pH                       3.400000
# sulphates                0.730000
# alcohol                 11.100000
# quality                  6.000000
# Name: 0.75, dtype: float64

# %%
maindt.columns = ['fixed_acidity','volatile_acidity','citric_acid','residual_sugar','chlorides','free_sulfur_dioxide','total_sulfur_dioxide','density','pH','sulphates','alcohol','quality']

# %%
q1 = maindt.quantile(0.25)
q3 = maindt.quantile(0.75)
iqr = q3-q1
maindt
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Cannot remove outlier by IQR as more than 20% data getting scraped

# %%
import numpy as np
maindt2 = maindt

# %%
maindt.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(20,50))
colcount = len(maindt.columns)
x=1
for col in maindt:
    if x <= colcount:
        ax= plt.subplot(10,3,x)
       # sns.distplot(maindt[col])
        sns.scatterplot(maindt[col],maindt['quality'],hue=maindt['quality'])
       # plt.scatter(y=maindt[col],x=maindt['quality'])
        plt.xlabel(col,fontsize=10)
    x=x+1
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# Finding corelation butween target and features

# %%
maindt.skew()
# Out:
# fixed_acidity           0.982751
# volatile_acidity        0.671593
# citric_acid             0.318337
# residual_sugar          4.540655
# chlorides               5.680347
# free_sulfur_dioxide     1.250567
# total_sulfur_dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
plt.figure(figsize=(10,10))
maindt.corr()['quality'].sort_values(ascending=False).drop(['quality']).plot(kind='bar', color='c')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(maindt.corr(), color = "k", annot=True  )
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per standard value of 0.7 or greater we consider high correlation but there seems to be no columns which are highly related

# %%
maindt['quality'] = [1 if x >= 7 else 0 for x in maindt['quality']]

# %% [markdown]
# As it was mentioned less than 7 to be considered bad wine and greater than 7 to be considered best

# %%
maindt.quality.value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
sns.countplot(maindt['quality'])
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
x= maindt.drop(columns=['quality'])
y= maindt['quality']

from imblearn.over_sampling import SMOTE
obj = SMOTE()
x, y = obj.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    1382
# 1    1382
# Name: quality, dtype: int64

# %%
sns.countplot(y)
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# Class imbalance issue is taken care of.

# %%
x.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    2764.000000       2764.000000  2764.000000     2764.000000
# mean        8.557369          0.474706     0.316756        2.570187
# std         1.831511          0.169733     0.193963        1.279757
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.200000          0.346433     0.150000        1.937486
# 50%         8.222941          0.440000     0.330000        2.200000
# 75%         9.700000          0.586168     0.467073        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  2764.000000          2764.000000           2764.000000  2764.000000
# mean      0.082515            15.004153             41.253053     0.996465
# std       0.039418            10.139923             30.561963     0.002004
# ...

# %% [markdown]
# As label vaues are changed to 1,0 we can use logistic regression as it is binary classification.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split , cross_val_score
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import classification_report
lrm = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=29)
lrm.fit(x_train,y_train)

lrscore = lrm.score(x_test,y_test)
print("Model Score", lrscore )
lrcvscore = cross_val_score(lrm,x,y,cv=5)
print("Cross Valudition", np.mean(lrcvscore) )
#lrpred = lrm.predict([y_test])
# Out:
# Model Score 0.4020723244005715
# Cross Valudition -0.22584225989745227

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)

dtcscore = dtc.score(x_test,y_test)
print("Model Score", dtcscore )
dtccvscore = cross_val_score(dtc,x,y,cv=5)
print("Cross Valudition", np.mean(dtccvscore) )
dtcpred = dtc.predict(x_test)
print("Cross Valudition", classification_report(y_test,dtcpred))
# Out:
# Model Score 0.894356005788712
# Cross Valudition 0.8679396965170219
# Cross Valudition               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.90       366
#            1       0.86      0.93      0.89       325
#
#     accuracy                           0.89       691
#    macro avg       0.90      0.90      0.89       691
# weighted avg       0.90      0.89      0.89       691

# %% [markdown]
#  DecisionTreeClassifier score is 89%
#  Cross Validation score is 87%
#  Accuracy score is 89%
#  Diff 2%

# %%
from sklearn.ensemble import RandomForestClassifier
rfcmodel = RandomForestClassifier()
rfcmodel.fit(x_train,y_train)

rfcscore = rfcmodel.score(x_test,y_test)
print("Model Score", dtcscore )
rfccvscore = cross_val_score(rfcmodel,x,y,cv=5)
print("Cross Valudition", np.mean(rfccvscore) )
rfcpred = rfcmodel.predict(x_test)
print("Cross Valudition", classification_report(y_test,rfcpred))
# Out:
# Model Score 0.894356005788712
# Cross Valudition 0.9044880362711953
# Cross Valudition               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93       366
#            1       0.90      0.96      0.93       325
#
#     accuracy                           0.93       691
#    macro avg       0.93      0.93      0.93       691
# weighted avg       0.93      0.93      0.93       691

# %% [markdown]
#  RandomForestClassifier score is 88%
#  Cross Validation score is 90%
#  Accuracy score is 93%
#  Diff 3%

# %%
svcmodel = SVC()
svcmodel.fit(x_train,y_train)
svcscore = svcmodel.score(x_test,y_test)
print("Model Score", svcscore )
svccvscore = cross_val_score(svcmodel,x,y,cv=5)
print("Cross Valudition", np.mean(svccvscore) )
svcpred = svcmodel.predict(x_test)
print("Cross Valudition", classification_report(y_test,svcpred))
# Out:
# Model Score 0.743849493487699
# Cross Valudition 0.7261118536572582
# Cross Valudition               precision    recall  f1-score   support
#
#            0       0.82      0.67      0.73       366
#            1       0.69      0.83      0.75       325
#
#     accuracy                           0.74       691
#    macro avg       0.75      0.75      0.74       691
# weighted avg       0.76      0.74      0.74       691

# %% [markdown]
# RandomForestClassifier score is 74%
# Cross Validation score is 72%
# Accuracy score is 74%
# Diff = 2%

# %% [markdown]
# With the difference of 2% Decision Tree Classifier has the best model.

# %% [markdown]
# Hyper Parameter Tuning

# %%
parameters = {
    'splitter' : ['best','random'],
    'criterion' : ['gini','entropy'],
    'max_features' : ['auto','sqrt','log2']
   
}

# %%
from sklearn.model_selection import GridSearchCV
gscv = GridSearchCV(DecisionTreeClassifier(),parameters,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']})

# %%
gscv.best_params_
# Out:
# {'criterion': 'gini', 'max_features': 'auto', 'splitter': 'best'}

# %%
dtc2 = DecisionTreeClassifier(criterion='gini',max_features='auto',splitter='best')
dtc2.fit(x_train,y_train)

dtcscore2 = dtc2.score(x_test,y_test)
print("Model Score", dtcscore )
dtccvscore2 = cross_val_score(dtc2,x,y,cv=5)
print("Cross Valudition", np.mean(dtccvscore2) )
dtcpred2 = dtc2.predict(x_test)
print("Cross Valudition", classification_report(y_test,dtcpred2))
# Out:
# Model Score 0.894356005788712
# Cross Valudition 0.84226288754357
# Cross Valudition               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       366
#            1       0.88      0.90      0.89       325
#
#     accuracy                           0.90       691
#    macro avg       0.90      0.90      0.90       691
# weighted avg       0.90      0.90      0.90       691

# %%
import joblib
joblib.dump(dtc2, "Final_Model.pkl")
# Out:
# ['Final_Model.pkl']
