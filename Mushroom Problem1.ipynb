# %%
import pandas as pd

# %%
dt = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/mushrooms.csv")

# %%
dt.nunique(axis=0)
# Out:
# class                        2
# cap-shape                    6
# cap-surface                  4
# cap-color                   10
# bruises                      2
# odor                         9
# gill-attachment              2
# gill-spacing                 2
# gill-size                    2
# gill-color                  12
# stalk-shape                  2
# stalk-root                   5
# stalk-surface-above-ring     4
# stalk-surface-below-ring     4
# stalk-color-above-ring       9
# stalk-color-below-ring       9
# veil-type                    1
# veil-color                   4
# ring-number                  3
# ring-type                    5
# spore-print-color            9
# population                   6
# habitat                      7
# dtype: int64

# %%
dt.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
num=1
for i in dt.columns:
    
    print(  i)
# Out:
# class
# cap-shape
# cap-surface
# cap-color
# bruises
# odor
# gill-attachment
# gill-spacing
# gill-size
# gill-color
# stalk-shape
# stalk-root
# stalk-surface-above-ring
# stalk-surface-below-ring
# stalk-color-above-ring
# stalk-color-below-ring
# veil-type
# veil-color
# ring-number
# ring-type
# spore-print-color
# population
# habitat

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LaEnMod = LabelEncoder()

# %%
dt2 = dt.apply(LaEnMod.fit_transform)

# %%
dt2
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
dt2.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
dt.drop(['veil-type'],axis=1)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# ...

# %%
dt=dt.nunique(axis=0)

# %%
dt
# Out:
# class                        2
# cap-shape                    6
# cap-surface                  4
# cap-color                   10
# bruises                      2
# odor                         9
# gill-attachment              2
# gill-spacing                 2
# gill-size                    2
# gill-color                  12
# stalk-shape                  2
# stalk-root                   5
# stalk-surface-above-ring     4
# stalk-surface-below-ring     4
# stalk-color-above-ring       9
# stalk-color-below-ring       9
# veil-type                    1
# veil-color                   4
# ring-number                  3
# ring-type                    5
# spore-print-color            9
# population                   6
# habitat                      7
# dtype: int64

# %%
dt2.nunique()
# Out:
# class                        2
# cap-shape                    6
# cap-surface                  4
# cap-color                   10
# bruises                      2
# odor                         9
# gill-attachment              2
# gill-spacing                 2
# gill-size                    2
# gill-color                  12
# stalk-shape                  2
# stalk-root                   5
# stalk-surface-above-ring     4
# stalk-surface-below-ring     4
# stalk-color-above-ring       9
# stalk-color-below-ring       9
# veil-type                    1
# veil-color                   4
# ring-number                  3
# ring-type                    5
# spore-print-color            9
# population                   6
# habitat                      7
# dtype: int64

# %%
listCol = []
for col in dt2:
    n = len(pd.unique(dt2[col]))
    if n >2:
        listCol.append(col)

# %%
pip install category_encoders
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from category_encoders import BinaryEncoder

# %%
BE = BinaryEncoder()
dt3 = BE.fit_transform(col=['cap-shape'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-6e93aba00b24> in <module>
#       1 BE = BinaryEncoder()
# ----> 2 dt3 = BE.fit_transform(col=['cap-shape'])
#       3
#
# TypeError: fit_transform() missing 1 required positional argument: 'X'

# %%
dt3 = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/mushrooms.csv")

# %%
dt5 = dt2.copy()

# %%
BE = BinaryEncoder(cols=listCol)
dt4 = BE.fit_transform(dt5)
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
dt4
# Out:
#       class  cap-shape_0  cap-shape_1  cap-shape_2  cap-shape_3  \
# 0         1            0            0            0            1
# 1         0            0            0            0            1
# 2         0            0            0            1            0
# 3         1            0            0            0            1
# 4         0            0            0            0            1
# ...     ...          ...          ...          ...          ...
# 8119      0            0            1            0            1
# 8120      0            0            0            0            1
# 8121      0            0            1            0            0
# 8122      1            0            1            0            1
# 8123      0            0            0            0            1
#
#       cap-surface_0  cap-surface_1  cap-surface_2  cap-color_0  cap-color_1  \
# 0                 0              0              1            0            0
# ...

# %%
dt4.describe()
# Out:
#              class  cap-shape_0  cap-shape_1  cap-shape_2  cap-shape_3  \
# count  8124.000000       8124.0  8124.000000  8124.000000  8124.000000
# mean      0.482029          0.0     0.490399     0.060069     0.555884
# std       0.499708          0.0     0.499939     0.237629     0.496898
# min       0.000000          0.0     0.000000     0.000000     0.000000
# 25%       0.000000          0.0     0.000000     0.000000     0.000000
# 50%       0.000000          0.0     0.000000     0.000000     1.000000
# 75%       1.000000          0.0     1.000000     0.000000     1.000000
# max       1.000000          0.0     1.000000     1.000000     1.000000
#
#        cap-surface_0  cap-surface_1  cap-surface_2  cap-color_0  cap-color_1  \
# count    8124.000000    8124.000000    8124.000000       8124.0  8124.000000
# mean        0.000492       0.684884       0.600197          0.0     0.009355
# std         0.022185       0.464591       0.489888          0.0     0.096274
# ...

# %%
dt4 != 0
# Out:
#       class  cap-shape_0  cap-shape_1  cap-shape_2  cap-shape_3  \
# 0      True        False        False        False         True
# 1     False        False        False        False         True
# 2     False        False        False         True        False
# 3      True        False        False        False         True
# 4     False        False        False        False         True
# ...     ...          ...          ...          ...          ...
# 8119  False        False         True        False         True
# 8120  False        False        False        False         True
# 8121  False        False         True        False        False
# 8122   True        False         True        False         True
# 8123  False        False        False        False         True
#
#       cap-surface_0  cap-surface_1  cap-surface_2  cap-color_0  cap-color_1  \
# 0             False          False           True        False        False
# ...

# %%
(dt4 != 0).any(axis=0)
# Out:
# class            True
# cap-shape_0     False
# cap-shape_1      True
# cap-shape_2      True
# cap-shape_3      True
#                 ...
# population_3     True
# habitat_0       False
# habitat_1        True
# habitat_2        True
# habitat_3        True
# Length: 72, dtype: bool

# %%
dt4 = dt4.loc[:, (dt4 != 0).any(axis=0)]

# %%
dt4
# Out:
#       class  cap-shape_1  cap-shape_2  cap-shape_3  cap-surface_0  \
# 0         1            0            0            1              0
# 1         0            0            0            1              0
# 2         0            0            1            0              0
# 3         1            0            0            1              0
# 4         0            0            0            1              0
# ...     ...          ...          ...          ...            ...
# 8119      0            1            0            1              0
# 8120      0            0            0            1              0
# 8121      0            1            0            0              0
# 8122      1            1            0            1              0
# 8123      0            0            0            1              0
#
#       cap-surface_1  cap-surface_2  cap-color_1  cap-color_2  cap-color_3  \
# 0                 0              1            0            0            0
# ...

# %%
dt4.count(axis=0)
# Out:
# class                         8124
# cap-shape_1                   8124
# cap-shape_2                   8124
# cap-shape_3                   8124
# cap-surface_0                 8124
# cap-surface_1                 8124
# cap-surface_2                 8124
# cap-color_1                   8124
# cap-color_2                   8124
# cap-color_3                   8124
# cap-color_4                   8124
# bruises                       8124
# odor_1                        8124
# odor_2                        8124
# odor_3                        8124
# odor_4                        8124
# gill-attachment               8124
# gill-spacing                  8124
# gill-size                     8124
# gill-color_1                  8124
# gill-color_2                  8124
# gill-color_3                  8124
# gill-color_4                  8124
# stalk-shape                   8124
# stalk-root_1                  8124
# stalk-root_2                  8124
# stalk-root_3                  8124
# ...

# %%
dt4.describe()
# Out:
#              class  cap-shape_1  cap-shape_2  cap-shape_3  cap-surface_0  \
# count  8124.000000  8124.000000  8124.000000  8124.000000    8124.000000
# mean      0.482029     0.490399     0.060069     0.555884       0.000492
# std       0.499708     0.499939     0.237629     0.496898       0.022185
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       0.000000     0.000000     0.000000     0.000000       0.000000
# 50%       0.000000     0.000000     0.000000     1.000000       0.000000
# 75%       1.000000     1.000000     0.000000     1.000000       0.000000
# max       1.000000     1.000000     1.000000     1.000000       1.000000
#
#        cap-surface_1  cap-surface_2  cap-color_1  cap-color_2  cap-color_3  \
# count    8124.000000    8124.000000  8124.000000  8124.000000  8124.000000
# mean        0.684884       0.600197     0.009355     0.449532     0.300345
# std         0.464591       0.489888     0.096274     0.497477     0.458436
# ...

# %%
import matplotlib.pyplot as plt

# %%
main = dt3['class'].unique()

# %%
columns = dt3['class'].value_counts()

# %%
columns
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
plt.subplot().bar(main,columns)
plt.subplot().set_xlabel('Class')  
plt.subplot().set_ylabel('Count') 
plt.show()
# Out:
# <ipython-input-37-a85ec96e8e00>:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot().set_xlabel('Class')
# <ipython-input-37-a85ec96e8e00>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot().set_ylabel('Count')

# %%
dt4.describe()
# Out:
#              class  cap-shape_1  cap-shape_2  cap-shape_3  cap-surface_0  \
# count  8124.000000  8124.000000  8124.000000  8124.000000    8124.000000
# mean      0.482029     0.490399     0.060069     0.555884       0.000492
# std       0.499708     0.499939     0.237629     0.496898       0.022185
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       0.000000     0.000000     0.000000     0.000000       0.000000
# 50%       0.000000     0.000000     0.000000     1.000000       0.000000
# 75%       1.000000     1.000000     0.000000     1.000000       0.000000
# max       1.000000     1.000000     1.000000     1.000000       1.000000
#
#        cap-surface_1  cap-surface_2  cap-color_1  cap-color_2  cap-color_3  \
# count    8124.000000    8124.000000  8124.000000  8124.000000  8124.000000
# mean        0.684884       0.600197     0.009355     0.449532     0.300345
# std         0.464591       0.489888     0.096274     0.497477     0.458436
# ...

# %%
import seaborn as sns

# %%
x = dt3.drop(columns=['class'])

# %%
 y = dt3['class']

# %%
len(dt3.columns)
# Out:
# 23

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber = 1
 
    
for col in x:
        if plotnumber < 23:
            ax= plt.subplot(3,3,plotnumber)
            sns.stripplot(y,x[col])
        plotnumber +=1    
plt.tight_layout()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
dt3
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
dt4
# Out:
#       class  cap-shape_1  cap-shape_2  cap-shape_3  cap-surface_0  \
# 0         1            0            0            1              0
# 1         0            0            0            1              0
# 2         0            0            1            0              0
# 3         1            0            0            1              0
# 4         0            0            0            1              0
# ...     ...          ...          ...          ...            ...
# 8119      0            1            0            1              0
# 8120      0            0            0            1              0
# 8121      0            1            0            0              0
# 8122      1            1            0            1              0
# 8123      0            0            0            1              0
#
#       cap-surface_1  cap-surface_2  cap-color_1  cap-color_2  cap-color_3  \
# 0                 0              1            0            0            0
# ...

# %%
dt4.class
# Out:
#   File "<ipython-input-49-56f61706049b>", line 1
#     dt4.class
#         ^
# SyntaxError: invalid syntax

# %%
dt5 = dt4.copy()

# %%
label2 = dt4['class']

# %%
features2 = dt4.drop('class',axis=1)

# %%
 from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(features2,label2, random_state = 3)

# %%
knnM = KNeighborsClassifier(n_neighbors=3)
knnM.fit(xtrain,ytrain)
knnM.score(xtest,ytest)
# Out:
# <ipython-input-121-00c211806696>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   knnM.fit(xtrain,ytrain)
# 1.0

# %%
dt3
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
label4 = dt3['class']

# %%
features4 = dt3.drop('class',axis=1)

# %%
label4 = pd.get_dummies(label4)['p']

# %%
features4 = pd.get_dummies(features4[features4.columns])

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(features4,label4, random_state=3)

# %%
knnM = KNeighborsClassifier(n_neighbors=3)
knnM.fit(xtrain,ytrain)
knnM.score(xtest,ytest)
# Out:
# 1.0

# %%
import joblib

# %%
joblib.dump(knnM, "mushroom_practice.pkl")
# Out:
# ['mushroom_practice.pkl']
